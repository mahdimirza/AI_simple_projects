# %% [markdown]
# ### Solving cutting stock problem using simulated anealing and hill climbing algorithms

# %% [markdown]
# # Hill_Climbing

# %%
import random
import copy
import math

# %%
class Solution:
    def __init__(self, req, stock):
        self.solution = req                   # intialize by input list
        self.stock = stock                    # length of stock

#############################################################################
    def generate_solution(self):
        random.shuffle(self.solution)           # generating a random solution by shuffling list

##############################################################################

# this function calculate the number of stocks we need for this order of list

    def calc_cost(self, req):
        res = 0
        sum = 0
        for i in range(len(req)):
            if(sum + req[i] < self.stock) :
                sum += req[i]
            else:
                res += 1
                sum = req[i]

        return res

################################################################################

# this function Runs HillClimbing Algorithm on random generated solution

    def Hill_Climbing(self):
        res = self.calc_cost(self.solution)
        while True:
            flag = 0
            for i in range(len(self.solution) - 1):
                for j in range(i, len(self.solution)):
                    ls = self.solution.copy()
                    ls[i], ls[j] = ls[j], ls[i]
                    if(self.calc_cost(ls) < res):
                        self.solution = ls
                        res = self.calc_cost(ls)
                        flag = 1


            if(flag == 0):
                break

        return(res)

####################################################################################

#print best order of input list which has been found

    def get_solution(self):
        print(self.solution)

####################################################################################

mylist1 = [106, 187, 914, 106, 33, 18, 402, 230, 507, 495, 609, 627, 346, 295, 312, 107, 716, 88, 106, 248,
          689, 115, 106, 218, 672, 618, 117, 805, 306, 753, 414, 84, 557, 266, 409, 144, 69, 116, 333, 88,
          264, 967, 180, 251, 71, 788, 581, 555, 988, 292, 60, 125, 532, 405, 170, 249, 181, 686, 283, 424,
          933, 23, 99, 135, 246, 337, 648, 753, 354, 518, 45, 286, 315, 370, 557, 463, 312, 284, 61, 412, 457,
          118, 268, 123, 232, 788, 678, 371, 171, 557, 549, 286, 356, 92, 148, 515, 301, 632, 987, 660, 868,
          92, 544, 211, 70, 75, 145, 125, 278, 441, 368, 351, 119, 662, 653, 186, 517, 43, 224, 506, 592, 501,
          149, 79, 241, 53, 80, 437, 46, 78, 149, 525, 149, 126, 365, 460, 280, 266, 109, 86]

#answer = 51 or less than 51

S1 = Solution(mylist1, 1000)  # you must assign stock length here ##################################
S1.generate_solution()
res = S1.Hill_Climbing()
print(res)

S1.get_solution()
# Out:
# 52
# [148, 125, 45, 678, 135, 149, 180, 78, 43, 149, 119, 346, 555, 402, 518, 627, 241, 106, 218, 118, 549, 106, 266, 170, 515, 463, 414, 987, 295, 648, 46, 145, 23, 224, 592, 716, 988, 92, 557, 232, 753, 84, 424, 125, 441, 351, 92, 71, 69, 266, 412, 557, 187, 371, 333, 618, 144, 278, 171, 532, 660, 284, 437, 86, 405, 211, 370, 126, 286, 264, 368, 312, 230, 753, 788, 409, 501, 967, 116, 70, 123, 672, 286, 609, 249, 79, 312, 248, 88, 788, 149, 301, 460, 805, 106, 107, 117, 557, 653, 251, 914, 18, 181, 246, 457, 517, 354, 109, 933, 495, 686, 292, 186, 53, 632, 61, 306, 365, 115, 868, 99, 581, 33, 337, 88, 544, 356, 525, 80, 283, 268, 506, 280, 689, 507, 315, 75, 662, 106, 60]

# %% [markdown]
# # Simulated_Anealing

# %%
class Solution:
    def __init__(self, req, stock):
        self.solution = req
        self.stock = stock
        self.T = None
        
#############################################################################
    def generate_solution(self):
        random.shuffle(self.solution)

##############################################################################


    def calc_cost(self, req):
        res = 1
        sum = 0
        for i in range(len(req)):
            if(sum + req[i] < self.stock) :
                sum += req[i]
            else:
                res += 1
                sum = req[i]

        return res

################################################################################

    def simulated_annealing(self, t0 = 10000, decrease_rate = .9999, t_end = 1e-9):
        self.T = t0
        res = len(self.solution)
        while(True):
            if(self.T < t_end or res < 115):  #assign min number of stocks##########################################
                return(res)
            
            l = random.sample(range(1, len(self.solution)), 2)
            ls = self.solution.copy()
            ls[l[0]], ls[l[1]] = ls[l[1]], ls[l[0]]

            Delta_E = self.calc_cost(self.solution) - self.calc_cost(ls)
            if(Delta_E > 0) :
                self.solution = ls
            elif random.random() < math.exp(Delta_E / self.T):
                self.solution = ls
            res = self.calc_cost(self.solution)

            self.T *= decrease_rate

####################################################################################
    def get_solution(self):
        print(self.solution)

####################################################################################

mylist1 = [6, 11, 288, 19, 18, 3, 6, 2, 1, 116, 17, 9, 2, 470, 224, 16, 3, 1, 7, 2, 25, 2, 1, 18, 5, 5, 92,
            1, 162, 8, 2, 153, 161, 8, 1, 17, 9, 5, 8, 244, 8, 134, 2, 1, 88, 11, 49, 8, 3, 1, 3, 6, 85, 2,
            1, 12, 201, 1, 14, 187, 7, 4, 245, 2, 6, 1, 2, 3, 1, 9, 106, 8, 5, 9, 10, 4, 9, 7, 1, 9, 1, 6,
            11, 8, 3, 7, 41, 7, 75, 5, 3, 6, 5, 3, 1, 166, 5, 2, 52, 21, 5, 7, 5, 5, 3, 110, 5, 3, 2, 4,
            2, 5, 271, 369, 134, 3, 282, 3, 1, 76, 12, 4, 16, 10, 12, 1, 2, 26, 1, 204, 14, 1, 4, 1, 118, 72,
            2, 2, 364, 2, 1, 196, 6, 331, 26, 14, 6, 159, 433, 3, 2, 1, 275, 7, 8, 1, 318, 5, 32, 4, 1, 17,
            8, 20, 21, 1, 3, 19, 386, 3, 172, 1, 17, 93, 138, 7, 8, 6, 157, 4, 6, 2, 7, 111, 34, 7, 159, 359, 
            6, 264, 131, 9, 5, 3, 36, 1, 6, 18, 8, 7, 116, 11, 5, 154, 1, 5, 120, 17, 16, 152, 2, 21, 5, 14, 
            7, 7, 174, 134, 24, 17, 3, 3, 4, 6, 6, 225, 10, 15, 7, 86, 2, 13, 5, 224, 15, 6, 1, 9, 2, 9, 3, 
            264, 152, 4, 14, 260, 124, 214, 17, 12, 10, 10, 3, 2, 4, 97, 313, 4, 1, 5, 16, 237, 5, 2, 9, 9, 
            10, 12, 1, 17, 311, 2, 9, 16, 9, 19, 22, 2, 10, 178, 3, 9, 1, 4, 9, 87, 321, 8, 10, 4, 183, 405, 
            5, 9, 7, 227, 14, 18, 205, 7, 14, 9, 4, 7, 2, 15, 6, 7, 204, 240, 99, 2, 4, 112, 314, 89, 198, 
            178, 8, 11, 7, 167, 124, 27, 6, 86, 11, 1, 19, 6, 3, 8, 1, 180, 1, 361, 3, 11, 5, 8, 28, 9, 1, 
            152, 6, 8, 27, 6, 191, 5, 3, 234, 3, 15, 1, 243, 1, 11, 4, 9, 255, 2, 6, 5, 6, 169, 92, 138, 3, 
            8, 1, 6, 6, 2, 3, 38, 2, 14, 21, 5, 8, 4, 1, 7, 5, 275, 9, 2, 11, 5, 8, 18, 13, 4, 67, 66, 111, 
            3, 3, 339, 1, 4, 13, 29, 147, 10, 3, 23, 5, 158, 7, 13, 1, 7, 1, 9, 4, 4, 4, 3, 2, 74, 98, 25, 
            335, 1, 24, 6, 243, 11, 167, 4, 4, 7, 10, 98, 8, 135, 4, 419, 14, 4, 15, 1, 6, 2, 12, 6, 11, 13, 
            8, 21, 6, 21, 147, 5, 8, 14, 11, 263, 4, 147, 411, 24, 16, 18, 1, 2, 90, 24, 2, 7, 5, 18, 21, 3, 
            319, 8, 138, 4, 5, 2, 1, 5, 7, 126, 68, 265, 9, 1, 6, 239, 9, 3, 3, 2, 160, 12, 3, 350, 3, 91, 9, 
            40, 10, 12, 5, 37, 2, 5, 16, 5, 6, 1, 11, 2, 3, 343, 12, 2, 130, 314, 5, 76, 9, 4, 11, 1, 3, 3, 
            1, 9, 186, 14, 2, 1, 4, 9, 1, 209, 5, 3, 7, 21, 174, 13, 4, 27, 255, 2, 298, 1, 7, 8, 9, 1, 12, 
            3, 6, 150, 16, 4, 2, 16, 133, 281, 1, 1, 38, 8, 15, 1, 1, 5, 2, 3, 4, 170, 2, 134, 263, 7, 10, 
            10, 6, 139, 2, 3, 13, 5, 163, 6, 109, 4, 229, 4, 199, 6, 228, 7, 7, 1, 13, 2, 167, 2, 8, 1, 2, 
            2, 1, 3, 14, 6, 7, 26, 49, 87, 14, 1, 8, 4, 35, 2, 13, 18, 184, 39, 132, 271, 1, 115, 45, 9, 5, 
            3, 66, 6, 144, 2, 152, 403, 5, 23, 5, 1, 1, 102, 3, 313, 1, 315, 6, 13, 2, 5, 9, 54, 7, 9, 458, 
            92, 15, 14, 3, 197, 6, 314, 7, 9, 2, 5, 108, 1, 18, 7, 7, 11, 3, 7, 1, 34, 1, 1, 3, 274, 61, 49, 
            9, 11, 7, 4, 43, 9, 7, 2, 12, 11, 11, 2, 4, 7, 6, 5, 144, 1, 4, 12, 34, 133, 3, 169, 189, 2, 6, 9, 
            4, 17, 7, 1, 8, 8, 3, 2, 2, 8, 5, 360, 15, 151, 79, 87, 277, 165, 399, 245, 78, 156, 86, 1, 3, 6, 
            1, 68, 2, 23, 2, 4, 290, 245, 280, 1, 6, 170, 152, 2, 2, 8, 4, 3, 2, 11, 7, 12, 250, 243, 2, 209, 
            6, 7, 153, 12, 225, 4, 5, 251, 2, 314, 6, 13, 4, 7, 125, 102, 1, 9, 170, 10, 50, 108, 2, 1, 43, 9, 
            3, 10, 430, 7, 1, 11, 1, 13, 4, 12, 2, 234, 14, 96, 5, 6, 128, 1, 3, 8, 8, 6, 479, 3, 1, 421, 4, 7, 
            2, 14, 9, 1, 16, 24, 3, 3, 2, 5, 10, 213, 12, 1, 8, 124, 279, 188, 3, 299, 92, 4, 23, 41, 10, 1, 3, 
            9, 2, 4, 13, 19, 2, 59, 2, 3, 3, 10]



S1 = Solution(mylist1, 500)    #you must assign stock_length here and min stocks in SA function where i have commented it
S1.generate_solution()
res = S1.simulated_annealing()
print(res)
S1.get_solution()
# Out:
# 109
# ...
